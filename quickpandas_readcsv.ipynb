# %%
import pandas as pd

# %%
df=pd.read_csv(r"/mnt/c/Users/Kwodwo/Downloads/data-modeling-in-power-bi/Datasets/manufacturing_data.csv",header=1)
df.head()
# Out:
#             id Geographic Area Name  Geo Footnote 2017 NAICS code  \
# 0  0400000US01              Alabama           NaN           31-33
# 1  0400000US01              Alabama           NaN           31-33
# 2  0400000US01              Alabama           NaN             311
# 3  0400000US01              Alabama           NaN             311
# 4  0400000US01              Alabama           NaN            3111
#
#    Industry group  2017 NAICS Footnote      Meaning of NAICS code  \
# 0             NaN                  NaN              Manufacturing
# 1             NaN                  NaN              Manufacturing
# 2             NaN                  NaN         Food manufacturing
# 3             NaN                  NaN         Food manufacturing
# 4          3111.0                  NaN  Animal food manufacturing
#
#    NAICS economic sector   SUBSECTOR  Industry level  Year  \
# 0                      31        NaN               2  2018
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 797 entries, 0 to 796
# Data columns (total 19 columns):
#  #   Column                                                                             Non-Null Count  Dtype
# ---  ------                                                                             --------------  -----
#  0   id                                                                                 797 non-null    object
#  1   Geographic Area Name                                                               797 non-null    object
#  2   Geo Footnote                                                                       0 non-null      float64
#  3   2017 NAICS code                                                                    797 non-null    object
#  4   Industry group                                                                     621 non-null    float64
# ...

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

model._get_param_names()
# Out:
# ['C',
#  'class_weight',
#  'dual',
#  'fit_intercept',
#  'intercept_scaling',
#  'l1_ratio',
#  'max_iter',
#  'multi_class',
#  'n_jobs',
#  'penalty',
#  'random_state',
#  'solver',
#  'tol',
#  'verbose',
#  'warm_start']

# %%
model.get_params()['C']
# Out:
# 1.0

# %%
model.set_params(C=5)
model.get_params()['C']
# Out:
# 5

# %%
# !conda list
# Out:
# # packages in environment at /home/kwodwo/anaconda3:
# #
# # Name                    Version                   Build  Channel
# _ipyw_jlab_nb_ext_conf    0.1.0            py39h06a4308_1
# _libgcc_mutex             0.1                        main
# _openmp_mutex             5.1                       1_gnu
# alabaster                 0.7.12             pyhd3eb1b0_0
# anaconda                  2022.10                  py39_0
# anaconda-client           1.11.0           py39h06a4308_0
# anaconda-navigator        2.3.1            py39h06a4308_0
# anaconda-project          0.11.1           py39h06a4308_0
# anyio                     3.5.0            py39h06a4308_0
# appdirs                   1.4.4              pyhd3eb1b0_0
# argon2-cffi               21.3.0             pyhd3eb1b0_0
# argon2-cffi-bindings      21.2.0           py39h7f8727e_0
# arrow                     1.2.2              pyhd3eb1b0_0
# astroid                   2.11.7           py39h06a4308_0
# ...
